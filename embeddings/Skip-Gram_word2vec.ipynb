# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:02, 11.7MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]
print(int_words[:20])
# Out:
# [5234, 3081, 11, 5, 194, 1, 3136, 45, 58, 155, 127, 741, 476, 10576, 133, 0, 27439, 1, 0, 102]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

t = 1e-5
wordcount = Counter(int_words)
total_words = len(int_words)
freqs = {word: count/total_words for word,count in wordcount.items()}
prob = {word: 1 - np.sqrt(t/freqs[word]) for word in wordcount}
train_words = [word for word in int_words if random.random() < (1 - prob[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    window = np.random.randint(1,window_size+1)
    #print(window,idx)
    #for i in range(1,window)
    target_words = {words[idx+i] if idx+i<len(words) else words[len(words)-1] for i in range(1,window)} and {words[idx-i] if idx-i>0 else words[0] for i in range(1,window) }
            
    return list(set(target_words))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,[None],name = 'inputs')
    labels = tf.placeholder(tf.int32, [None,None], name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding), minval=-1,maxval= 1), name='weights') # create embedding weight matrix here [n_vocab X n_embedding]
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w, biases=softmax_b,
      labels=labels,
      inputs=embed, num_sampled=n_sampled, num_classes= n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6553 0.0745 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6138 0.0686 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4961 0.0679 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5863 0.0674 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4919 0.0673 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5188 0.0674 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5505 0.0686 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5323 0.0692 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4884 0.0677 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4306 0.0691 sec/batch
# Nearest to american: akihabara, cordell, guidelines, subset, positivism, reprisal, tune, mold,
# Nearest to often: rose, thatched, pears, shahada, astarte, resurrected, tivoli, shoreline,
# Nearest to may: merits, detonating, microbiological, despotic, aykroyd, truths, formulates, savas,
# Nearest to as: moods, derisively, stray, zadok, skirt, hallows, rush, sark,
# Nearest to but: shackleton, desai, ntc, lungs, cossack, aeolian, plane, mugwort,
# Nearest to th: budapest, otoe, malta, crocker, invaded, hua, usmc, embedding,
# Nearest to other: anglorum, doreen, batman, orang, photocopies, srinagar, wh, embedding,
# Nearest to history: style, hybrid, sinking, rivest, hopkins, usability, vcjd, phraseology,
# Nearest to engineering: counterclockwise, spectacular, lubin, negotiators, rightfully, hyperplane, jungian, bipolar,
# Nearest to numerous: clap, wakshul, bolder, rupp, lance, morihiro, exhorts, universally,
# Nearest to magazine: disrespect, historic, fornax, posto, vechten, sprague, constitutionalism, luncheon,
# Nearest to pressure: nigra, glossy, bandleaders, netherlands, delineation, polskiej, sumo, normalize,
# Nearest to construction: centrum, corrective, relation, eszterh, vivace, prevents, mitsotakis, omits,
# Nearest to consists: bbc, defects, ultraviolet, revolutionaries, law, oil, peterborough, fascism,
# Nearest to san: virial, leisurely, pune, observables, superbly, samkhya, theistic, almagro,
# Nearest to smith: farid, their, playfair, hestia, increments, cautiously, jagan, zebras,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5433 0.0695 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4211 0.0686 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.4320 0.0691 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.3533 0.0696 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.3481 0.0699 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.3434 0.0697 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.2705 0.0701 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.2624 0.0709 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.1646 0.0706 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.1906 0.0709 sec/batch
# Nearest to american: akihabara, cordell, subset, guidelines, tune, positivism, reprisal, mathematically,
# Nearest to often: rose, shoreline, filmmaker, separate, ne, spiritism, admire, resurrected,
# Nearest to may: merits, truths, spin, aykroyd, coordinate, despotic, made, five,
# Nearest to as: force, derisively, journeys, beginning, skirt, rush, such, moods,
# Nearest to but: shackleton, swamped, cleveland, sexual, consistent, recalls, lungs, rotates,
# Nearest to th: malta, budapest, invaded, association, crocker, commonplace, otoe, laypeople,
# Nearest to other: than, site, and, anglorum, in, eventually, wh, systems,
# Nearest to history: style, hybrid, usability, permanent, rivest, sinking, physicists, hopkins,
# Nearest to engineering: counterclockwise, negotiators, spectacular, nernst, lubin, jungian, hyperplane, blatantly,
# Nearest to numerous: clap, bolder, universally, lance, morihiro, wakshul, change, polynomial,
# Nearest to magazine: disrespect, historic, scored, fornax, posto, vechten, overgrowth, logistics,
# Nearest to pressure: glossy, nigra, bandleaders, netherlands, delineation, robespierre, normalize, sexual,
# Nearest to construction: relation, corrective, prevents, centrum, time, adaptations, vivace, eszterh,
# Nearest to consists: bbc, law, defects, oil, ultraviolet, revolutionaries, extremely, kahn,
# Nearest to san: superbly, observables, virial, theistic, code, pune, leisurely, kyanite,
# Nearest to smith: their, farid, hestia, playfair, cautiously, increments, zebras, jagan,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 5.1412 0.0725 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 5.0928 0.0720 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 5.0422 0.0714 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 5.0262 0.0718 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.9281 0.0722 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.9774 0.0723 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.9210 0.0714 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8749 0.0709 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8931 0.0707 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8849 0.0710 sec/batch
# Nearest to american: guidelines, akihabara, cordell, tune, subset, positivism, mathematically, enabling,
# Nearest to often: rose, separate, ne, shoreline, filmmaker, admire, resurrected, crowd,
# Nearest to may: merits, spin, truths, still, coordinate, metres, microbiological, title,
# Nearest to as: moods, rush, registration, beginning, journeys, force, derisively, fail,
# Nearest to but: plane, shackleton, consistent, swamped, cleveland, sexual, lungs, largely,
# Nearest to th: budapest, malta, invaded, association, crocker, consequences, commonplace, animated,
# Nearest to other: equal, than, suffer, systems, anglorum, doreen, site, manner,
# Nearest to history: style, permanent, usability, hybrid, centered, chief, physicists, browsers,
# Nearest to engineering: counterclockwise, negotiators, spectacular, nernst, asic, interact, blatantly, warm,
# Nearest to numerous: universally, clap, polynomial, flawed, license, change, bolder, points,
# Nearest to magazine: historic, disrespect, scored, fornax, logistics, status, patent, posto,
# Nearest to pressure: netherlands, glossy, robespierre, make, sexual, mid, provinces, nigra,
# Nearest to construction: relation, corrective, prevents, time, measurement, adaptations, centrum, significant,
# Nearest to consists: law, bbc, defects, oil, ultraviolet, revolutionaries, extremely, fascism,
# Nearest to san: observables, code, superbly, virial, theistic, billions, kyanite, transport,
# Nearest to smith: their, farid, hestia, cautiously, playfair, increments, jagan, zebras,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8897 0.0724 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8179 0.0706 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.8153 0.0702 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7694 0.0709 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.8257 0.0705 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7876 0.0704 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7722 0.0701 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7673 0.0702 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7646 0.0701 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.7161 0.0722 sec/batch
# Nearest to american: akihabara, guidelines, tune, cordell, reprisal, enabling, rimmer, actively,
# Nearest to often: rose, shoreline, crowd, int, separate, ne, resurrected, admire,
# Nearest to may: merits, truths, spin, still, coordinate, microbiological, aykroyd, liberties,
# Nearest to as: moods, registration, rush, fail, force, beginning, stray, labor,
# Nearest to but: shackleton, consistent, plane, lungs, sexual, cleveland, swamped, reject,
# Nearest to th: budapest, invaded, malta, consequences, crocker, proclaimed, association, cessation,
# Nearest to other: equal, suffer, than, systems, doreen, orang, anglorum, prove,
# Nearest to history: style, usability, hybrid, permanent, sinking, centered, physicists, browsers,
# Nearest to engineering: negotiators, counterclockwise, spectacular, interact, asic, nernst, blatantly, warm,
# Nearest to numerous: universally, clap, polynomial, flawed, lance, bolder, license, mesopotamia,
# Nearest to magazine: historic, disrespect, scored, patent, fornax, greene, logistics, purge,
# Nearest to pressure: netherlands, glossy, robespierre, sexual, provinces, nigra, illegally, mid,
# Nearest to construction: relation, corrective, prevents, measurement, time, adaptations, centrum, ny,
# Nearest to consists: defects, law, oil, bbc, revolutionaries, ultraviolet, inventors, fascism,
# Nearest to san: observables, virial, superbly, code, theistic, billions, day, ignore,
# Nearest to smith: their, farid, cautiously, hestia, playfair, increments, zebras, relinquishing,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7358 0.0724 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.7278 0.0707 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6809 0.0711 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6876 0.0702 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6840 0.0704 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6785 0.0713 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6382 0.0523 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5834 0.0703 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5232 0.0705 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5270 0.0699 sec/batch
# Nearest to american: akihabara, tune, singer, reprisal, politician, davis, cordell, comedian,
# Nearest to often: rose, shoreline, shahada, admire, int, lanes, offense, clothes,
# Nearest to may: merits, truths, microbiological, aykroyd, spin, coordinate, still, detonating,
# Nearest to as: moods, registration, derisively, rush, stray, such, fail, rigid,
# Nearest to but: shackleton, consistent, plane, lungs, aeolian, desai, swamped, sexual,
# Nearest to th: malta, budapest, invaded, hua, otoe, rebuilt, crocker, usmc,
# Nearest to other: orang, systems, equal, than, prove, doreen, suffer, batman,
# Nearest to history: style, usability, sinking, permanent, rivest, hybrid, poorest, browsers,
# Nearest to engineering: counterclockwise, negotiators, spectacular, nernst, interact, asic, rightfully, blatantly,
# Nearest to numerous: universally, clap, bolder, polynomial, lance, flawed, license, mesopotamia,
# Nearest to magazine: disrespect, scored, historic, cautionary, greene, fornax, patent, logistics,
# Nearest to pressure: glossy, netherlands, nigra, illegally, biodiversity, provinces, make, sexual,
# Nearest to construction: corrective, relation, measurement, prevents, centrum, time, interquartile, ny,
# Nearest to consists: defects, law, revolutionaries, oil, ultraviolet, bbc, inventors, fascism,
# Nearest to san: virial, superbly, billions, day, theistic, observables, inked, kyanite,
# Nearest to smith: farid, hestia, increments, cautiously, playfair, jagan, their, justin,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5075 0.0728 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5089 0.0720 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4827 0.0729 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5356 0.0719 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4845 0.0711 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4881 0.0702 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4970 0.0705 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4336 0.0708 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4307 0.0709 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4297 0.0713 sec/batch
# Nearest to american: akihabara, reprisal, cordell, tune, davis, singer, politician, guidelines,
# Nearest to often: rose, int, shahada, clothes, shoreline, offense, admire, simplest,
# Nearest to may: merits, truths, microbiological, still, traps, glycogen, gal, coordinate,
# Nearest to as: moods, registration, such, derisively, fail, stray, beginning, rigid,
# Nearest to but: shackleton, consistent, plane, lungs, desai, aeolian, reject, horizontally,
# Nearest to th: budapest, invaded, malta, rebuilt, hua, otoe, annexed, crocker,
# Nearest to other: than, orang, prove, equal, mapped, doreen, systems, batman,
# Nearest to history: style, usability, rivest, permanent, poorest, sinking, centered, chief,
# Nearest to engineering: negotiators, counterclockwise, interact, spectacular, nernst, asic, residues, bipolar,
# Nearest to numerous: bolder, universally, clap, lance, mesopotamia, flawed, polynomial, exhorts,
# Nearest to magazine: disrespect, cautionary, historic, greene, scored, purge, glitter, luncheon,
# Nearest to pressure: glossy, biodiversity, nigra, netherlands, even, engine, make, illegally,
# Nearest to construction: corrective, relation, prevents, interquartile, centrum, staircase, measurement, eszterh,
# Nearest to consists: defects, law, ultraviolet, revolutionaries, oil, inventors, bbc, fascism,
# Nearest to san: virial, day, superbly, billions, inked, lake, july, kyanite,
# Nearest to smith: farid, increments, hestia, playfair, cautiously, bernard, jagan, shatner,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4575 0.0720 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4240 0.0702 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4479 0.0706 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4246 0.0718 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4310 0.0707 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4226 0.0721 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3725 0.0710 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3966 0.0714 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4325 0.0715 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3900 0.0714 sec/batch
# Nearest to american: singer, akihabara, davis, politician, cordell, tune, reprisal, frank,
# Nearest to often: rose, shahada, simplest, int, clothes, profiles, pears, entrants,
# Nearest to may: merits, truths, microbiological, still, spin, coordinate, counterparts, detonating,
# Nearest to as: such, fail, registration, moods, hallows, derisively, stray, antonescu,
# Nearest to but: shackleton, consistent, desai, lungs, swamped, aeolian, plane, sexual,
# Nearest to th: invaded, budapest, malta, hua, rebuilt, otoe, proclaimed, wilbert,
# Nearest to other: than, orang, prove, mapped, suffer, traditionalists, hobby, coerce,
# Nearest to history: style, rivest, usability, permanent, enver, sinking, poorest, gravestone,
# Nearest to engineering: negotiators, interact, counterclockwise, nernst, asic, spectacular, bipolar, jungian,
# Nearest to numerous: bolder, universally, clap, flawed, lance, polynomial, mesopotamia, cascade,
# Nearest to magazine: greene, disrespect, cautionary, historic, scored, luncheon, constitutionalism, overgrowth,
# Nearest to pressure: glossy, even, engine, biodiversity, nigra, determining, abundance, camcorder,
# Nearest to construction: corrective, relation, interquartile, staircase, prevents, eszterh, centrum, kosovo,
# Nearest to consists: defects, law, ultraviolet, revolutionaries, inventors, oil, customary, fascism,
# Nearest to san: inked, lake, day, virial, superbly, kyanite, july, colonised,
# Nearest to smith: farid, playfair, hestia, bernard, cautiously, jagan, justin, increments,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3918 0.0728 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3847 0.0721 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3589 0.0702 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3615 0.0720 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3971 0.0728 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3829 0.0723 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4116 0.0722 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4025 0.0727 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3481 0.0725 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3465 0.0719 sec/batch
# Nearest to american: akihabara, davis, tune, singer, cordell, frank, reprisal, baseball,
# Nearest to often: rose, profiles, shahada, simplest, entrants, pears, clothes, microstate,
# Nearest to may: merits, microbiological, truths, counterparts, coordinate, aykroyd, still, detonating,
# Nearest to as: moods, registration, hallows, such, fail, derisively, antonescu, zug,
# Nearest to but: shackleton, desai, reject, aeolian, swamped, brandt, consistent, lungs,
# Nearest to th: budapest, invaded, otoe, hua, rebuilt, proclaimed, malta, circa,
# Nearest to other: orang, than, traditionalists, in, coerce, batman, manner, sweating,
# Nearest to history: style, rivest, usability, enver, poorest, permanent, fsb, phraseology,
# Nearest to engineering: negotiators, interact, asic, counterclockwise, nernst, bipolar, jungian, seaside,
# Nearest to numerous: bolder, universally, antics, clap, exhorts, flawed, cascade, mesopotamia,
# Nearest to magazine: greene, disrespect, delany, scored, cautionary, glitter, historic, fornax,
# Nearest to pressure: glossy, engine, even, biodiversity, abundance, nigra, camcorder, make,
# Nearest to construction: corrective, relation, interquartile, centrum, staircase, measurement, time, eszterh,
# Nearest to consists: law, defects, ultraviolet, fascism, revolutionaries, oil, amanullah, customary,
# Nearest to san: lake, colonised, inked, day, kyanite, virial, july, campus,
# Nearest to smith: farid, playfair, hestia, bernard, cautiously, justin, jagan, seventies,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3642 0.0727 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3364 0.0717 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.4059 0.0715 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3980 0.0718 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4055 0.0716 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3095 0.0714 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3386 0.0724 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3533 0.0705 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2410 0.0712 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3133 0.0720 sec/batch
# Nearest to american: singer, davis, actor, leonard, akihabara, musician, frank, actress,
# Nearest to often: profiles, shahada, rose, pears, entrants, sasl, reddish, simplest,
# Nearest to may: merits, microbiological, truths, coordinate, counterparts, aykroyd, detonating, bilinear,
# Nearest to as: moods, such, hallows, registration, fail, antonescu, zug, sark,
# Nearest to but: shackleton, desai, aeolian, reject, swamped, asked, actuated, brandt,
# Nearest to th: budapest, invaded, rebuilt, otoe, circa, malta, proclaimed, hua,
# Nearest to other: orang, than, coerce, traditionalists, sweating, doreen, batman, suffer,
# Nearest to history: style, rivest, enver, usability, fsb, physicists, phraseology, poorest,
# Nearest to engineering: negotiators, asic, interact, nernst, counterclockwise, bipolar, prosaic, jungian,
# Nearest to numerous: bolder, universally, clap, antics, mesopotamia, exhorts, flawed, parts,
# Nearest to magazine: greene, cautionary, glitter, weekly, delany, disrespect, scored, fornax,
# Nearest to pressure: glossy, biodiversity, nigra, engine, abundance, even, heavy, camcorder,
# Nearest to construction: corrective, relation, interquartile, measurement, domestic, centrum, eszterh, petrochemicals,
# Nearest to consists: defects, law, ultraviolet, fascism, oil, customary, amanullah, close,
# Nearest to san: july, inked, railroad, day, colonised, lake, pune, superbly,
# Nearest to smith: playfair, farid, bernard, hestia, cautiously, justin, jagan, otis,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3384 0.0728 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3055 0.0706 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3467 0.0315 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2520 0.0710 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2249 0.0707 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2242 0.0700 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2087 0.0705 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2024 0.0723 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2081 0.0709 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1673 0.0718 sec/batch
# Nearest to american: singer, akihabara, davis, leonard, frank, paleontologist, cordell, mandy,
# Nearest to often: rose, profiles, shahada, offense, clothes, reddish, pears, sasl,
# Nearest to may: merits, microbiological, truths, aykroyd, counterparts, theorizing, coordinate, zvi,
# Nearest to as: moods, such, hallows, registration, sark, stray, fail, kbe,
# Nearest to but: shackleton, desai, aeolian, asked, centrist, actuated, swamped, horizontally,
# Nearest to th: budapest, clemente, qin, uncritical, otoe, hua, circa, centuries,
# Nearest to other: orang, than, traditionalists, in, coerce, sweating, octaves, batman,
# Nearest to history: enver, style, rivest, articles, usability, physicists, fsb, phraseology,
# Nearest to engineering: negotiators, asic, nernst, counterclockwise, interact, rightfully, jungian, bipolar,
# Nearest to numerous: bolder, parts, antics, universally, clap, selector, exhorts, flawed,
# Nearest to magazine: greene, glitter, cautionary, delany, weekly, disrespect, christensen, scored,
# Nearest to pressure: glossy, nigra, biodiversity, engine, even, heavy, netherlands, abundance,
# Nearest to construction: corrective, interquartile, relation, staircase, centrum, petrochemicals, airport, prevents,
# Nearest to consists: defects, law, ultraviolet, customary, amanullah, ravine, fascism, close,
# Nearest to san: railroad, inked, july, colonised, superbly, lake, kyanite, campus,
# Nearest to smith: farid, playfair, hestia, bernard, jagan, cautiously, justin, otis,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2238 0.0717 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1967 0.0708 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1819 0.0716 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1292 0.0728 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1578 0.0712 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1474 0.0706 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1660 0.0704 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1437 0.0713 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1852 0.0721 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1575 0.0708 sec/batch
# Nearest to american: akihabara, paleontologist, davis, singer, cordell, mandy, tune, reprisal,
# Nearest to often: rose, profiles, shahada, reddish, clothes, entrants, confused, option,
# Nearest to may: merits, microbiological, coordinate, counterparts, truths, bilinear, theorizing, glycogen,
# Nearest to as: such, moods, zug, fail, registration, involvements, some, mya,
# Nearest to but: desai, shackleton, aeolian, asked, horizontally, centrist, bhangra, deconstructionist,
# Nearest to th: otoe, qin, clemente, circa, uncritical, hua, budapest, invaded,
# Nearest to other: orang, than, coerce, octaves, traditionalists, in, threading, and,
# Nearest to history: enver, style, articles, rivest, usability, encyclopedia, phraseology, fsb,
# Nearest to engineering: negotiators, asic, nernst, interact, counterclockwise, immunoglobulins, jungian, rightfully,
# Nearest to numerous: bolder, universally, parts, clap, antics, exhorts, wakshul, travelogue,
# Nearest to magazine: weekly, greene, glitter, delany, cautionary, christensen, heinemann, disrespect,
# Nearest to pressure: glossy, nigra, biodiversity, engine, abundance, even, pressures, oxygen,
# Nearest to construction: corrective, relation, interquartile, petrochemicals, prevents, measurement, staircase, airport,
# Nearest to consists: defects, law, ultraviolet, customary, amanullah, fascism, ravine, spondees,
# Nearest to san: railroad, inked, kyanite, superbly, colonised, july, almagro, dunfermline,
# Nearest to smith: playfair, farid, hestia, cautiously, justin, jagan, bernard, otis,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1592 0.0726 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2326 0.0703 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1589 0.0707 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1288 0.0704 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1553 0.0708 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1581 0.0703 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1834 0.0703 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1279 0.0707 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1058 0.0699 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1757 0.0705 sec/batch
# Nearest to american: singer, akihabara, davis, musician, cordell, paleontologist, mandy, tune,
# Nearest to often: rose, shahada, profiles, reddish, clothes, entrants, techniques, confused,
# Nearest to may: merits, microbiological, counterparts, theorizing, bilinear, coordinate, conclude, liberties,
# Nearest to as: such, moods, zug, shoppers, involvements, surges, brochs, ethnocentric,
# Nearest to but: asked, shackleton, desai, aeolian, indifference, lungs, actuated, deconstructionist,
# Nearest to th: otoe, qin, circa, clemente, uncritical, hua, centuries, fuge,
# Nearest to other: orang, traditionalists, coerce, than, octaves, anglorum, sweating, threading,
# Nearest to history: articles, enver, style, rivest, encyclopedia, phraseology, usability, physicists,
# Nearest to engineering: asic, negotiators, nernst, interact, engineers, jungian, technology, bipolar,
# Nearest to numerous: antics, bolder, universally, travelogue, clap, undivided, wakshul, prizren,
# Nearest to magazine: weekly, delany, greene, glitter, christensen, cautionary, heinemann, msnbc,
# Nearest to pressure: glossy, biodiversity, nigra, pressures, abundance, oxygen, even, engine,
# Nearest to construction: corrective, relation, petrochemicals, interquartile, staircase, prevents, measurement, eszterh,
# Nearest to consists: law, defects, customary, ultraviolet, spondees, amanullah, fascism, close,
# Nearest to san: railroad, inked, almagro, colonised, kyanite, dunfermline, superbly, july,
# Nearest to smith: playfair, farid, justin, hestia, rolle, jagan, cautiously, bernard,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2193 0.0719 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1753 0.0704 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1747 0.0702 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1663 0.0707 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1186 0.0707 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1088 0.0720 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1404 0.0719 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1093 0.0710 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1618 0.0709 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1976 0.0706 sec/batch
# Nearest to american: singer, davis, akihabara, musician, actress, paleontologist, mandy, rossellini,
# Nearest to often: rose, reddish, shahada, clothes, dak, embargoes, profiles, entrants,
# Nearest to may: merits, microbiological, zvi, aykroyd, theorizing, counterparts, liberties, bilinear,
# Nearest to as: moods, such, brochs, hallows, involvements, surges, antonescu, ethnocentric,
# Nearest to but: shackleton, desai, aeolian, asked, indifference, centrist, agnostics, promises,
# Nearest to th: clemente, circa, centuries, qin, otoe, fuge, uncritical, hua,
# Nearest to other: orang, traditionalists, than, coerce, anglorum, quebecers, revolting, sweating,
# Nearest to history: articles, rivest, enver, encyclopedia, phraseology, style, physicists, gravestone,
# Nearest to engineering: asic, negotiators, nernst, interact, engineers, technology, jungian, immunoglobulins,
# Nearest to numerous: antics, universally, undivided, travelogue, bolder, prizren, clap, flawed,
# Nearest to magazine: weekly, glitter, christensen, greene, delany, cautionary, heinemann, ruston,
# Nearest to pressure: glossy, nigra, biodiversity, pressures, abundance, engine, even, netherlands,
# Nearest to construction: corrective, relation, emplacements, staircase, interquartile, petrochemicals, prevents, centrum,
# Nearest to consists: law, customary, defects, amanullah, spondees, fascism, kahn, ultraviolet,
# Nearest to san: railroad, almagro, colonised, july, inked, kyanite, candlestick, superbly,
# Nearest to smith: playfair, farid, justin, cautiously, bernard, hestia, rolle, jagan,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2435 0.0719 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1118 0.0707 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1286 0.0711 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1282 0.0710 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0194 0.0711 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.0991 0.0709 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1211 0.0703 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0963 0.0705 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1394 0.0117 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0935 0.0705 sec/batch
# Nearest to american: singer, akihabara, paleontologist, davis, actress, rossellini, cordell, mandy,
# Nearest to often: rose, reddish, clothes, dak, shahada, techniques, profiles, embargoes,
# Nearest to may: merits, microbiological, bilinear, aykroyd, theorizing, counterparts, coordinate, zvi,
# Nearest to as: moods, such, brochs, zanjeer, hallows, repulsion, ethnocentric, shoppers,
# Nearest to but: desai, shackleton, aeolian, centrist, finalized, indifference, asked, lungs,
# Nearest to th: clemente, centuries, circa, qin, otoe, disrespectful, uncritical, fuge,
# Nearest to other: orang, than, traditionalists, batman, sweating, octaves, coerce, and,
# Nearest to history: articles, enver, encyclopedia, rivest, phraseology, fsb, style, poorest,
# Nearest to engineering: asic, negotiators, nernst, technology, engineers, interact, educational, jungian,
# Nearest to numerous: universally, antics, undivided, prizren, travelogue, bolder, parts, selector,
# Nearest to magazine: weekly, glitter, christensen, delany, cautionary, greene, ruston, fornax,
# Nearest to pressure: glossy, nigra, pressures, biodiversity, engine, netherlands, abundance, even,
# Nearest to construction: corrective, relation, emplacements, petrochemicals, unpaved, interquartile, highways, prevents,
# Nearest to consists: law, customary, defects, spondees, mahor, amanullah, district, kahn,
# Nearest to san: railroad, inked, almagro, candlestick, francisco, july, colonised, kyanite,
# Nearest to smith: playfair, farid, justin, hestia, rolle, religio, bernard, jagan,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0327 0.0715 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0204 0.0702 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0304 0.0702 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0245 0.0700 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0329 0.0709 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0059 0.0713 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0313 0.0711 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0679 0.0705 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0674 0.0715 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9928 0.0713 sec/batch
# Nearest to american: singer, paleontologist, akihabara, mandy, nicholls, cemac, davis, visitor,
# Nearest to often: rose, clothes, reddish, techniques, dak, profiles, offense, entrants,
# Nearest to may: merits, microbiological, aykroyd, theorizing, zvi, counterparts, comforts, funding,
# Nearest to as: such, brochs, moods, zanjeer, involvements, repulsion, zug, relied,
# Nearest to but: shackleton, aeolian, horizontally, desai, indifference, passes, finalized, envious,
# Nearest to th: clemente, centuries, circa, qin, otoe, uncritical, dynasty, samanid,
# Nearest to other: orang, than, traditionalists, and, asian, rheumatology, coerce, anglorum,
# Nearest to history: articles, enver, encyclopedia, rivest, style, fsb, phraseology, gravestone,
# Nearest to engineering: asic, engineers, nernst, technology, negotiators, interact, educational, education,
# Nearest to numerous: universally, antics, undivided, prizren, bolder, parts, travelogue, selector,
# Nearest to magazine: weekly, christensen, glitter, delany, cautionary, ruston, publishes, fornax,
# Nearest to pressure: glossy, nigra, pressures, biodiversity, netherlands, engine, illegally, australis,
# Nearest to construction: corrective, relation, emplacements, petrochemicals, staircase, highways, prevents, unpaved,
# Nearest to consists: law, customary, defects, spondees, district, mahor, historically, amanullah,
# Nearest to san: railroad, almagro, francisco, fresno, inked, colonised, kyanite, july,
# Nearest to smith: farid, playfair, hestia, justin, rolle, religio, npr, cautiously,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9973 0.0730 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9768 0.0724 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9916 0.0713 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0246 0.0713 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0239 0.0724 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0052 0.0714 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0133 0.0710 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0498 0.0708 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0245 0.0710 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.9790 0.0707 sec/batch
# Nearest to american: singer, paleontologist, akihabara, davis, mandy, nicholls, cemac, rimmer,
# Nearest to often: rose, techniques, reddish, entrants, clothes, confused, spiritism, shahada,
# Nearest to may: microbiological, merits, counterparts, theorizing, textures, provability, conclude, bilinear,
# Nearest to as: such, brochs, moods, repulsion, ethnocentric, shoppers, zanjeer, antonescu,
# Nearest to but: shackleton, indifference, aeolian, horizontally, desai, finalized, centrist, tiberian,
# Nearest to th: otoe, circa, clemente, centuries, qin, uncritical, fuge, savard,
# Nearest to other: orang, traditionalists, than, coerce, rheumatology, and, anglorum, octaves,
# Nearest to history: articles, encyclopedia, enver, tailoring, rivest, phraseology, fsb, gravestone,
# Nearest to engineering: engineers, asic, nernst, negotiators, technology, educational, interact, postgraduate,
# Nearest to numerous: antics, universally, undivided, prizren, parts, flawed, selector, bolder,
# Nearest to magazine: weekly, christensen, glitter, delany, greene, ruston, publishes, cautionary,
# Nearest to pressure: glossy, pressures, nigra, biodiversity, engine, illegally, even, netherlands,
# Nearest to construction: corrective, relation, emplacements, staircase, interquartile, petrochemicals, starting, prevents,
# Nearest to consists: law, customary, spondees, defects, kahn, district, smaller, amanullah,
# Nearest to san: railroad, almagro, kyanite, francisco, fresno, colonised, alou, superbly,
# Nearest to smith: farid, playfair, justin, rolle, religio, cautiously, npr, newman,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.9896 0.0718 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0605 0.0702 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0215 0.0705 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.9935 0.0702 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0020 0.0699 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.9933 0.0708 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0260 0.0711 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0245 0.0728 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0739 0.0708 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0136 0.0703 sec/batch
# Nearest to american: singer, paleontologist, akihabara, nicholls, mandy, davis, actress, rossellini,
# Nearest to often: rose, anglicanism, dak, entrants, clothes, shahada, spiritism, embargoes,
# Nearest to may: microbiological, merits, theorizing, counterparts, textures, aykroyd, zvi, comforts,
# Nearest to as: brochs, such, moods, antonescu, repulsion, ethnocentric, journeys, sark,
# Nearest to but: shackleton, aeolian, obedient, desai, finalized, indifference, asked, tiberian,
# Nearest to th: centuries, circa, clemente, century, qin, uncritical, samanid, otoe,
# Nearest to other: orang, traditionalists, than, coerce, anglorum, rheumatology, threading, octaves,
# Nearest to history: articles, encyclopedia, phraseology, enver, style, topics, poorest, reordered,
# Nearest to engineering: engineers, asic, nernst, negotiators, technology, educational, postgraduate, interact,
# Nearest to numerous: antics, undivided, universally, prizren, flawed, parts, selector, bolder,
# Nearest to magazine: weekly, christensen, glitter, ruston, delany, greene, mckeon, cassettes,
# Nearest to pressure: pressures, glossy, nigra, biodiversity, engine, illegally, even, corpuscles,
# Nearest to construction: corrective, relation, emplacements, staircase, petrochemicals, interquartile, starting, highways,
# Nearest to consists: law, customary, spondees, defects, district, amanullah, kahn, rhythmic,
# Nearest to san: almagro, kyanite, fresno, francisco, colonised, candlestick, superbly, railroad,
# Nearest to smith: farid, playfair, otis, justin, npr, rolle, religio, cautiously,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0060 0.0716 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9535 0.0705 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0049 0.0704 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 3.9827 0.0708 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0113 0.0709 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0645 0.0711 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0654 0.0707 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.9825 0.0713 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9687 0.0716 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 3.9876 0.0705 sec/batch
# Nearest to american: singer, paleontologist, actress, actor, akihabara, davis, venezuelan, nicholls,
# Nearest to often: rose, reddish, dak, clothes, anglicanism, entrants, spiritism, shahada,
# Nearest to may: microbiological, merits, aykroyd, comforts, textures, counterparts, refered, theorizing,
# Nearest to as: brochs, such, moods, repulsion, antonescu, zanjeer, relied, sark,
# Nearest to but: aeolian, shackleton, finalized, desai, indifference, obedient, centrist, swamped,
# Nearest to th: centuries, circa, century, clemente, qin, samanid, otoe, uncritical,
# Nearest to other: orang, than, traditionalists, coerce, asian, rheumatology, anglorum, revolting,
# Nearest to history: articles, encyclopedia, phraseology, enver, databases, topics, rivest, style,
# Nearest to engineering: engineers, asic, nernst, technology, negotiators, educational, postgraduate, interact,
# Nearest to numerous: antics, undivided, universally, prizren, flawed, parts, selector, travelogue,
# Nearest to magazine: weekly, christensen, glitter, ruston, delany, greene, mckeon, cassettes,
# Nearest to pressure: glossy, pressures, nigra, biodiversity, engine, illegally, netherlands, creek,
# Nearest to construction: corrective, emplacements, relation, staircase, petrochemicals, starting, interquartile, highways,
# Nearest to consists: customary, law, spondees, district, smaller, sov, mahor, defects,
# Nearest to san: fresno, almagro, francisco, candlestick, kyanite, alou, superbly, railroad,
# Nearest to smith: farid, playfair, justin, rights, otis, cautiously, seventies, rolle,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9309 0.0715 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9467 0.0702 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9827 0.0706 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9866 0.0710 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0409 0.0705 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.9940 0.0622 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9264 0.0722 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9142 0.0707 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9647 0.0700 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9202 0.0705 sec/batch
# Nearest to american: singer, paleontologist, actress, actor, nicholls, akihabara, musician, venezuelan,
# Nearest to often: rose, emplacements, reddish, clothes, dak, shahada, spiritism, entrants,
# Nearest to may: microbiological, aykroyd, refered, merits, zvi, comforts, concluding, theorizing,
# Nearest to as: brochs, such, moods, zanjeer, relied, egalitarian, repulsion, shoppers,
# Nearest to but: finalized, desai, aeolian, shackleton, obedient, indifference, centrist, tiberian,
# Nearest to th: centuries, century, circa, samanid, qin, clemente, dynasty, uncritical,
# Nearest to other: orang, revolting, rheumatology, traditionalists, coerce, than, asian, batman,
# Nearest to history: articles, encyclopedia, databases, enver, phraseology, tailoring, rivest, style,
# Nearest to engineering: engineers, asic, nernst, negotiators, technology, educational, robotics, interact,
# Nearest to numerous: antics, undivided, prizren, universally, selector, parts, flawed, travelogue,
# Nearest to magazine: weekly, christensen, glitter, ruston, fornax, mckeon, cassettes, greene,
# Nearest to pressure: pressures, glossy, nigra, biodiversity, illegally, creek, engine, netherlands,
# Nearest to construction: emplacements, corrective, relation, petrochemicals, staircase, highways, starting, chongqing,
# Nearest to consists: customary, law, spondees, mahor, district, kahn, adema, historically,
# Nearest to san: francisco, fresno, almagro, candlestick, alou, kyanite, superbly, railroad,
# Nearest to smith: farid, playfair, justin, rights, otis, rolle, hestia, cautiously,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9175 0.0722 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8898 0.0719 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9462 0.0712 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9845 0.0710 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9431 0.0710 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9311 0.0715 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8454 0.0714 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.8825 0.0711 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8626 0.0721 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.8735 0.0710 sec/batch
# Nearest to american: singer, akihabara, paleontologist, cemac, islander, nicholls, venezuelan, actress,
# Nearest to often: emplacements, rose, reddish, clothes, dak, common, anglicanism, shahada,
# Nearest to may: microbiological, comforts, textures, refered, theorizing, merits, aykroyd, provability,
# Nearest to as: such, brochs, moods, nonmetals, shoppers, etching, confidences, triangulation,
# Nearest to but: finalized, shackleton, desai, horizontally, tiberian, aeolian, dangrek, asked,
# Nearest to th: century, samanid, circa, centuries, otoe, qin, clemente, uncritical,
# Nearest to other: orang, traditionalists, than, rheumatology, and, revolting, batman, empower,
# Nearest to history: articles, encyclopedia, databases, topics, enver, fsb, tailoring, style,
# Nearest to engineering: engineers, asic, technology, negotiators, nernst, education, robotics, educational,
# Nearest to numerous: antics, undivided, prizren, selector, parts, flawed, universally, kowloon,
# Nearest to magazine: weekly, christensen, glitter, ruston, monthly, fornax, luncheon, cautionary,
# Nearest to pressure: pressures, glossy, nigra, biodiversity, creek, illegally, engine, corpuscles,
# Nearest to construction: corrective, emplacements, relation, staircase, petrochemicals, starting, highways, chongqing,
# Nearest to consists: customary, spondees, law, district, rhythmic, kahn, adema, historically,
# Nearest to san: fresno, francisco, almagro, alou, osaka, candlestick, kyanite, volgograd,
# Nearest to smith: farid, playfair, justin, seventies, otis, hestia, fisher, cautiously,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9305 0.0726 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9383 0.0719 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.8730 0.0721 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9759 0.0729 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9415 0.0721 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.8725 0.0720 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9315 0.0714 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9398 0.0710 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.8964 0.0715 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.8838 0.0714 sec/batch
# Nearest to american: singer, actress, actor, paleontologist, musician, nicholls, davis, akihabara,
# Nearest to often: rose, emplacements, confused, dak, int, shahada, anglicanism, common,
# Nearest to may: microbiological, aykroyd, theorizing, concluding, conclude, refered, merits, comforts,
# Nearest to as: such, brochs, shoppers, moods, some, kenesaw, egalitarian, falcone,
# Nearest to but: desai, finalized, aeolian, indifference, obedient, munda, horizontally, closet,
# Nearest to th: century, qin, samanid, centuries, circa, clemente, otoe, uncritical,
# Nearest to other: traditionalists, orang, rheumatology, than, anglorum, empower, batman, coerce,
# Nearest to history: articles, encyclopedia, topics, tailoring, databases, fsb, enver, rivest,
# Nearest to engineering: engineers, asic, nernst, technology, interact, robotics, negotiators, education,
# Nearest to numerous: antics, undivided, flawed, selector, prizren, universally, parts, awareness,
# Nearest to magazine: weekly, christensen, glitter, ruston, fornax, monthly, comp, delany,
# Nearest to pressure: nigra, pressures, glossy, biodiversity, corpuscles, creek, illegally, engine,
# Nearest to construction: corrective, relation, emplacements, staircase, petrochemicals, constructing, cathedrals, starting,
# Nearest to consists: customary, law, spondees, rhythmic, magistrate, kahn, district, defects,
# Nearest to san: francisco, fresno, almagro, alou, kyanite, superbly, railroad, candlestick,
# Nearest to smith: farid, playfair, fisher, otis, seventies, justin, rights, cautiously,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9390 0.0732 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.8953 0.0713 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9033 0.0713 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9390 0.0712 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9271 0.0714 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9390 0.0713 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9093 0.0709 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.8791 0.0720 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.8832 0.0718 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9329 0.0720 sec/batch
# Nearest to american: singer, paleontologist, actress, americans, akihabara, nicholls, davis, actor,
# Nearest to often: rose, entrants, dak, emplacements, common, anglicanism, dragsters, used,
# Nearest to may: microbiological, aykroyd, refered, concluding, conclude, theorizing, misconduct, comforts,
# Nearest to as: such, brochs, moods, shoppers, egalitarian, some, kenesaw, plosives,
# ...
# Nearest to san: francisco, fresno, almagro, nueva, diego, kyanite, candlestick, superbly,
# Nearest to smith: farid, rights, fisher, hestia, lineman, kirkuk, newman, playfair,
# Epoch 8/10 Iteration: 36100 Avg. Training loss: 3.8680 0.0712 sec/batch
# Epoch 8/10 Iteration: 36200 Avg. Training loss: 3.8004 0.0707 sec/batch
# Epoch 8/10 Iteration: 36300 Avg. Training loss: 3.8129 0.0700 sec/batch
# Epoch 8/10 Iteration: 36400 Avg. Training loss: 3.7089 0.0703 sec/batch
# Epoch 8/10 Iteration: 36500 Avg. Training loss: 3.7144 0.0701 sec/batch
# Epoch 8/10 Iteration: 36600 Avg. Training loss: 3.7279 0.0708 sec/batch
# Epoch 8/10 Iteration: 36700 Avg. Training loss: 3.7180 0.0701 sec/batch
# Epoch 8/10 Iteration: 36800 Avg. Training loss: 3.7824 0.0700 sec/batch
# Epoch 8/10 Iteration: 36900 Avg. Training loss: 3.7404 0.0700 sec/batch
# Epoch 8/10 Iteration: 37000 Avg. Training loss: 3.7946 0.0709 sec/batch
# Nearest to american: americans, singer, mccourt, paleontologist, islander, actress, activist, actor,
# Nearest to often: dak, emplacements, most, entrants, common, hallucinogen, used, digimon,
# Nearest to may: aykroyd, microbiological, archduke, of, jensen, june, prophetess, five,
# Nearest to as: the, called, some, such, brochs, created, in, cognomen,
# Nearest to but: so, a, heuvelmans, munda, hunky, obedient, trondheim, canopus,
# Nearest to th: century, centuries, otoe, circa, dynasty, afc, samanid, atahualpa,
# Nearest to other: and, rheumatology, wollaston, in, however, dedham, the, orang,
# Nearest to history: articles, encyclopedia, topics, hump, tailoring, mauryan, showing, nils,
# Nearest to engineering: engineers, robotics, asic, specialization, disciplines, accredited, opencourseware, negotiators,
# Nearest to numerous: antics, neocolonialism, parts, undivided, tightened, flawed, kowloon, grotto,
# Nearest to magazine: weekly, ruston, christensen, glitter, cassettes, cuff, comp, magazines,
# Nearest to pressure: pressures, nigra, creek, leaking, biodiversity, atmospheres, foundered, accommodations,
# Nearest to construction: emplacements, cathedrals, building, corrective, brokerage, petrochemicals, constructing, boring,
# Nearest to consists: magistrate, spondees, phrygia, rhythmic, turboprops, branches, inflatable, adema,
# Nearest to san: francisco, fresno, almagro, diego, candlestick, nueva, superbly, alou,
# Nearest to smith: farid, rights, hestia, fisher, kirkuk, pye, dolores, newman,
# Epoch 9/10 Iteration: 37100 Avg. Training loss: 3.7499 0.0558 sec/batch
# Epoch 9/10 Iteration: 37200 Avg. Training loss: 3.7680 0.0714 sec/batch
# Epoch 9/10 Iteration: 37300 Avg. Training loss: 3.6964 0.0713 sec/batch
# Epoch 9/10 Iteration: 37400 Avg. Training loss: 3.7644 0.0700 sec/batch
# Epoch 9/10 Iteration: 37500 Avg. Training loss: 3.6720 0.0703 sec/batch
# Epoch 9/10 Iteration: 37600 Avg. Training loss: 3.7139 0.0705 sec/batch
# Epoch 9/10 Iteration: 37700 Avg. Training loss: 3.6427 0.0718 sec/batch
# Epoch 9/10 Iteration: 37800 Avg. Training loss: 3.7770 0.0707 sec/batch
# Epoch 9/10 Iteration: 37900 Avg. Training loss: 3.7562 0.0706 sec/batch
# Epoch 9/10 Iteration: 38000 Avg. Training loss: 3.7460 0.0699 sec/batch
# Nearest to american: americans, singer, mccourt, islander, paleontologist, actress, actor, rimmer,
# Nearest to often: dak, emplacements, common, entrants, digimon, leavis, dragsters, most,
# Nearest to may: aykroyd, archduke, microbiological, gives, of, prophetess, uh, anchoring,
# Nearest to as: the, called, in, some, brochs, such, kenesaw, cognomen,
# Nearest to but: canopus, so, heuvelmans, a, obedient, munda, hunky, eyelashes,
# Nearest to th: century, centuries, circa, otoe, afc, samanid, dynasty, atahualpa,
# Nearest to other: and, the, rheumatology, however, in, dedham, which, wollaston,
# Nearest to history: articles, encyclopedia, topics, showing, tailoring, hump, mauryan, nils,
# Nearest to engineering: engineers, robotics, asic, specialization, negotiators, accredited, opencourseware, singapore,
# Nearest to numerous: antics, neocolonialism, parts, tightened, undivided, flawed, kowloon, gentrification,
# Nearest to magazine: ruston, weekly, glitter, cassettes, cuff, christensen, magazines, intercity,
# Nearest to pressure: pressures, nigra, creek, atmospheres, corpuscles, sears, foundered, accommodations,
# Nearest to construction: cathedrals, emplacements, building, brokerage, corrective, constructing, petrochemicals, rails,
# Nearest to consists: phrygia, spondees, rhythmic, branches, inflatable, magistrate, haji, quorum,
# Nearest to san: francisco, fresno, almagro, candlestick, superbly, nueva, jose, diego,
# Nearest to smith: farid, hestia, fisher, rights, kirkuk, dolores, logs, woodruff,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.7533 0.0716 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.6191 0.0707 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.7353 0.0709 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.6735 0.0711 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.6731 0.0703 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.7133 0.0703 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.7572 0.0708 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.6806 0.0707 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.7413 0.0704 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8019 0.0700 sec/batch
# Nearest to american: americans, singer, mccourt, islander, paleontologist, actress, rimmer, buckskin,
# Nearest to often: dak, most, entrants, leavis, policymakers, digimon, option, anglicanism,
# Nearest to may: microbiological, aykroyd, archduke, of, gives, prophetess, uh, conclude,
# Nearest to as: the, called, some, such, in, created, cognomen, never,
# Nearest to but: so, heuvelmans, hunky, a, canopus, adjoint, munda, obedient,
# Nearest to th: century, centuries, circa, otoe, afc, perkin, enlil, atahualpa,
# Nearest to other: and, the, however, in, dedham, rheumatology, traditionalists, which,
# Nearest to history: articles, topics, encyclopedia, tailoring, showing, mauryan, hump, ostrogoths,
# Nearest to engineering: engineers, robotics, opencourseware, specialization, postgraduate, disciplines, accredited, asic,
# Nearest to numerous: antics, neocolonialism, flawed, inclined, undivided, gentrification, subscribe, kurdistan,
# Nearest to magazine: ruston, weekly, cassettes, glitter, christensen, cuff, newspaper, comp,
# Nearest to pressure: pressures, nigra, creek, accommodations, atmospheres, leaking, corpuscles, sears,
# Nearest to construction: building, cathedrals, corrective, emplacements, constructing, rails, brokerage, boring,
# Nearest to consists: rhythmic, spondees, phrygia, branches, firebird, magistrate, rlc, adema,
# Nearest to san: francisco, fresno, almagro, nueva, superbly, diego, kyanite, jose,
# Nearest to smith: farid, hestia, fisher, kirkuk, lineman, rights, dolores, logs,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.6996 0.0727 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.7197 0.0710 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.7437 0.0702 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.7242 0.0709 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.7259 0.0703 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.7814 0.0703 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.7478 0.0703 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7199 0.0709 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.7482 0.0708 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.7262 0.0704 sec/batch
# Nearest to american: americans, singer, mccourt, islander, paleontologist, asian, akihabara, actress,
# Nearest to often: dak, entrants, used, common, leavis, anglicanism, most, digimon,
# Nearest to may: aykroyd, of, microbiological, archduke, conclude, lite, uh, gives,
# Nearest to as: called, the, in, some, such, created, never, cognomen,
# Nearest to but: so, a, heuvelmans, munda, indifference, canopus, oes, obedient,
# Nearest to th: century, centuries, circa, otoe, afc, dynasty, perkin, enlil,
# Nearest to other: and, however, the, dedham, in, rheumatology, traditionalists, wollaston,
# Nearest to history: articles, topics, encyclopedia, tailoring, showing, ostrogoths, mauryan, nils,
# Nearest to engineering: engineers, robotics, asic, interact, jungian, opencourseware, specialization, johns,
# Nearest to numerous: antics, neocolonialism, tightened, undivided, kurdistan, hiv, inclined, flawed,
# Nearest to magazine: ruston, weekly, cassettes, christensen, glitter, newspaper, cuff, magazines,
# Nearest to pressure: pressures, nigra, atmospheres, biodiversity, creek, notoriously, corpuscles, leaking,
# Nearest to construction: cathedrals, building, corrective, emplacements, rails, petrochemicals, brokerage, constructing,
# Nearest to consists: rhythmic, firebird, spondees, phrygia, rlc, comprising, kahn, turboprops,
# Nearest to san: francisco, fresno, almagro, nueva, superbly, kyanite, candlestick, diego,
# Nearest to smith: fisher, hestia, farid, kirkuk, dolores, newman, logs, woodruff,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.7473 0.0715 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.7379 0.0704 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7075 0.0707 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7318 0.0710 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.7737 0.0714 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.6840 0.0705 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.8402 0.0704 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.7864 0.0700 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.7990 0.0698 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7208 0.0704 sec/batch
# Nearest to american: americans, singer, mccourt, islander, paleontologist, rimmer, brandauer, actress,
# Nearest to often: dak, common, entrants, used, generally, leavis, most, hallucinogen,
# Nearest to may: aykroyd, of, archduke, microbiological, june, uh, lite, eligible,
# Nearest to as: the, called, in, created, some, such, initially, never,
# Nearest to but: a, so, munda, canopus, the, heuvelmans, adjoint, hunky,
# Nearest to th: century, circa, otoe, centuries, dynasty, afc, qin, muscat,
# Nearest to other: and, however, rheumatology, dedham, the, wollaston, including, in,
# Nearest to history: articles, topics, encyclopedia, showing, hump, ostrogoths, mauryan, tailoring,
# Nearest to engineering: engineers, robotics, specialization, asic, opencourseware, jungian, postgraduate, johns,
# Nearest to numerous: antics, neocolonialism, created, undivided, kurdistan, thyssen, tightened, flawed,
# Nearest to magazine: ruston, weekly, cuff, glitter, magazines, cassettes, christensen, newspaper,
# Nearest to pressure: pressures, nigra, creek, accommodations, foundered, biodiversity, leaking, notoriously,
# Nearest to construction: cathedrals, building, rails, emplacements, brokerage, corrective, boring, constructing,
# Nearest to consists: phrygia, rhythmic, spondees, firebird, magistrate, branches, haji, adema,
# Nearest to san: francisco, fresno, almagro, diego, nueva, candlestick, kyanite, dei,
# Nearest to smith: fisher, hestia, farid, dolores, rights, newman, woodruff, kirkuk,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.6608 0.0709 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.7451 0.0702 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.6530 0.0706 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.7418 0.0700 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7298 0.0700 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.7141 0.0701 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.7928 0.0342 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7280 0.0701 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7083 0.0707 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.6956 0.0718 sec/batch
# Nearest to american: americans, singer, mccourt, paleontologist, islander, actor, actress, activist,
# Nearest to often: dak, entrants, used, generally, most, which, common, emplacements,
# Nearest to may: of, archduke, aykroyd, june, anchoring, microbiological, gives, prophetess,
# Nearest to as: called, the, in, some, such, created, never, brochs,
# Nearest to but: a, munda, heuvelmans, so, canopus, hunky, finalized, sacco,
# Nearest to th: century, centuries, circa, otoe, dynasty, samanid, muscat, qin,
# Nearest to other: and, dedham, rheumatology, however, in, the, which, wollaston,
# Nearest to history: articles, topics, encyclopedia, showing, hump, tailoring, ostrogoths, histories,
# Nearest to engineering: engineers, robotics, specialization, asic, opencourseware, jungian, negotiators, postgraduate,
# Nearest to numerous: antics, tightened, neocolonialism, leeds, thyssen, created, falcon, kurdistan,
# Nearest to magazine: weekly, ruston, cuff, glitter, cassettes, christensen, magazines, newspaper,
# Nearest to pressure: pressures, nigra, accommodations, biodiversity, notoriously, creek, foundered, leaking,
# Nearest to construction: cathedrals, rails, brokerage, building, boring, emplacements, corrective, nameplate,
# Nearest to consists: phrygia, spondees, rhythmic, branches, rlc, firebird, magistrate, customary,
# Nearest to san: francisco, fresno, almagro, candlestick, diego, nueva, jose, tattoo,
# Nearest to smith: fisher, hestia, dolores, farid, rights, woodruff, logs, newman,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7053 0.0721 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-b1d3869cd0d6> in <module>()
#      18             feed = {inputs: x,
#      19                     labels: np.array(y)[:, None]}
# ---> 20             train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
#      21
#      22             loss += train_loss
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/carnd/anaconda3/envs/dl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
